# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage

# %%
# Initialize the model
# "qwen2.5-coder:7b" is the model name you used in 'ollama pull'
llm = ChatOllama(
    model="qwen2.5-coder:7b",
    temperature=0,  # Set to 0 for consistent coding results
)

# %%
# Define your prompt
message = HumanMessage(content="Write a Python function to find the factorial of a number.")

# %%
# Invoke the model
response = llm.invoke([message])

# Print the code output
print(response.content)

# %%
for chunk in llm.stream("i have virtual environment setup on this folder please how to make a requirements.txt file that contains the necessary libraries"):
    print(chunk.content, end="", flush=True)
# Out:
# To create a `requirements.txt` file for your Python project, you can follow these steps:
#
# 1. **Activate Your Virtual Environment**:
#    Before generating the `requirements.txt`, make sure your virtual environment is activated.
#
#    - On Windows:
#      ```sh
#      .\venv\Scripts\activate
#      ```
#
#    - On macOS/Linux:
#      ```sh
#      source venv/bin/activate
#      ```
#
# 2. **Install Required Packages**:
#    If you haven't already installed the packages you need, do so using `pip`. For example:
#    ```sh
#    pip install numpy pandas matplotlib
#    ```
#
# 3. **Generate `requirements.txt`**:
#    Once your virtual environment is activated and all necessary packages are installed, you can generate the `requirements.txt` file by running:
#    ```sh
#    pip freeze > requirements.txt
#    ```
#
#    This command will create a `requirements.txt` file in the current directory with a list of all installed packages along with their versions.
#
# ...
